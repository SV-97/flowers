# %%
import numpy as np
import matplotlib.pyplot as plt

nx = plt.imread("nx.png")
ny = plt.imread("ny.png")
assert nx.shape == ny.shape

nx -= 0.5
ny -= 0.5

plt.streamplot(
    np.linspace(0,1, num=nx.shape[1]),
    np.linspace(0,1, num=ny.shape[0]),
    nx,
    ny,
)
